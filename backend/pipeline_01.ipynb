# %%
from dotenv import load_dotenv
import os
from langchain_ollama import ChatOllama, OllamaEmbeddings

# %%
llm = ChatOllama(
    model = "llama3.2:3b"
)

# %%
llm.invoke("Hey")
# Out:
# AIMessage(content='How can I help you today?', additional_kwargs={}, response_metadata={'model': 'llama3.2:3b', 'created_at': '2026-07-22T08:19:10.004925492Z', 'done': True, 'done_reason': 'stop', 'total_duration': 9833383136, 'load_duration': 9377627172, 'prompt_eval_count': 26, 'prompt_eval_duration': 352880000, 'eval_count': 8, 'eval_duration': 96693000, 'logprobs': None, 'model_name': 'llama3.2:3b', 'model_provider': 'ollama'}, id='lc_run--019f88e8-19c8-7540-9a0c-25d354281ece-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 26, 'output_tokens': 8, 'total_tokens': 34})

# %%
embedding_model = OllamaEmbeddings(
    model = "nomic-embed-text",
)
